# %% [markdown]
# # task1

# %%
import pandas as pd
cont=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/contracts/Contracts.csv")
cont
# Out:
#   ContractName         DealType   StartDate     EndDate  Volume Granularity  \
# 0           S1             Swap  2017-01-01  2017-03-31   20000       Daily
# 1           S2             Swap  2017-01-01  2018-12-31    1000      Hourly
# 2           O1  European option  2017-06-01  2017-07-15   10000       Daily
# 3           O2  European option  2018-10-01  2019-09-30    1000      Hourly
#
#    StrikePrice  Premium   PriceName
# 0          3.0      NaN   Henry Hub
# 1         21.0      NaN    HB_NORTH
# 2          2.9      0.1  GDA_TETSTX
# 3         31.5      3.0  HB_HOUSTON

# %%
gda=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/fuelPrices/GDA_TETSTX.csv")
henry=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/fuelPrices/Henry Hub.csv")
gda
# Out:
#         Variable        Date  Price
# 0     GDA_TETSTX  2019-05-01  2.490
# 1     GDA_TETSTX  2019-04-30  2.420
# 2     GDA_TETSTX  2019-04-29  2.445
# 3     GDA_TETSTX  2019-04-28  2.445
# 4     GDA_TETSTX  2019-04-27  2.445
# ...          ...         ...    ...
# 1942  GDA_TETSTX  2014-01-05  4.185
# 1943  GDA_TETSTX  2014-01-04  4.185
# 1944  GDA_TETSTX  2014-01-03  4.170
# 1945  GDA_TETSTX  2014-01-02  4.165
# 1946  GDA_TETSTX  2014-01-01  4.165
#
# [1947 rows x 3 columns]

# %%
plant=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/plantParameters/Plant_Parameters.csv")
plant
# Out:
#    PlantName  Year  Month PowerPriceName FuelPriceName  Capacity  HeatRate  \
# 0      Alpha  2017      1     HB_HOUSTON     Henry Hub       100       9.2
# 1      Alpha  2017      2     HB_HOUSTON     Henry Hub        98       9.4
# 2      Alpha  2017      3     HB_HOUSTON     Henry Hub        96       9.6
# 3      Alpha  2017      4     HB_HOUSTON     Henry Hub        94       9.8
# 4      Alpha  2017      5     HB_HOUSTON     Henry Hub        92      10.0
# 5      Alpha  2017      6     HB_HOUSTON     Henry Hub        90      10.0
# 6      Alpha  2017      7     HB_HOUSTON     Henry Hub        90      10.0
# 7      Alpha  2017      8     HB_HOUSTON     Henry Hub        92      10.0
# 8      Alpha  2017      9     HB_HOUSTON     Henry Hub        94       9.8
# 9      Alpha  2017     10     HB_HOUSTON     Henry Hub        96       9.6
# 10     Alpha  2017     11     HB_HOUSTON     Henry Hub        98       9.4
# ...

# %%
e16=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/powerPrices/ERCOT_DA_Prices_2016.csv")
e17=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/powerPrices/ERCOT_DA_Prices_2017.csv")
e18=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/powerPrices/ERCOT_DA_Prices_2018.csv")
e19=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/powerPrices/ERCOT_DA_Prices_2019.csv")

# %% [markdown]
# # task2

# %%
e17
# Out:
#                        Date SettlementPoint  Price
# 0       2017-01-01 00:00:00       HB_BUSAVG  23.23
# 1       2017-01-01 00:00:00      HB_HOUSTON  23.23
# 2       2017-01-01 00:00:00       HB_HUBAVG  23.23
# 3       2017-01-01 00:00:00        HB_NORTH  23.23
# 4       2017-01-01 00:00:00        HB_SOUTH  23.23
# ...                     ...             ...    ...
# 122621  2017-12-31 23:00:00         LZ_LCRA  21.71
# 122622  2017-12-31 23:00:00        LZ_NORTH  21.76
# 122623  2017-12-31 23:00:00        LZ_RAYBN  21.78
# 122624  2017-12-31 23:00:00        LZ_SOUTH  22.39
# 122625  2017-12-31 23:00:00         LZ_WEST  22.90
#
# [122626 rows x 3 columns]

# %%
t2=pd.concat([e16,e17,e18,e19])
t2=t2.reset_index(drop=True)
import datetime
t2.Date=t2.Date.apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
t2group=t2.groupby([t2.SettlementPoint,t2.Date.dt.year,t2.Date.dt.month])
t2
# Out:
#                       Date SettlementPoint  Price
# 0      2016-01-01 00:00:00       HB_BUSAVG  18.42
# 1      2016-01-01 00:00:00      HB_HOUSTON  18.42
# 2      2016-01-01 00:00:00       HB_HUBAVG  18.42
# 3      2016-01-01 00:00:00        HB_NORTH  18.43
# 4      2016-01-01 00:00:00        HB_SOUTH  18.38
# ...                    ...             ...    ...
# 497315 2019-12-31 23:00:00         LZ_LCRA  14.53
# 497316 2019-12-31 23:00:00        LZ_NORTH  14.48
# 497317 2019-12-31 23:00:00        LZ_RAYBN  14.48
# 497318 2019-12-31 23:00:00        LZ_SOUTH  14.70
# 497319 2019-12-31 23:00:00         LZ_WEST  16.78
#
# [497320 rows x 3 columns]

# %%
t2_mean=t2group.mean()
t2_max=t2group.max()
t2_min=t2group.min()
t2_std=t2group.std()

# %%
t2_mean.index.names=['SettlementPoint', 'year', 'month']
t2_max.index.names=['SettlementPoint', 'year', 'month']
t2_min.index.names=['SettlementPoint', 'year', 'month']
t2_std.index.names=['SettlementPoint', 'year', 'month']

# %%
# t2_mean=t2_mean.reset_index()
# t2_max=t2_max.reset_index()
# t2_min=t2_min.reset_index()
# t2_std=t2_std.reset_index()

# %% [markdown]
# # task3

# %%
import numpy as np
t2group3=t2.groupby([t2.SettlementPoint,t2.Date.dt.year,t2.Date.dt.month,t2.Date.dt.date,t2.Date.dt.hour])
t3=t2group3.mean()
t3.index.names=['SettlementPoint', 'year', 'month', "date",'hour']
t3=t3.reset_index()
# g=t3.groupby([t2.SettlementPoint,t2.Date.dt.year,t2.Date.dt.month,t2.Date.dt.hour])
t3
# Out:
#        SettlementPoint  year  month        date  hour  Price
# 0            HB_BUSAVG  2016      1  2016-01-01     0  18.42
# 1            HB_BUSAVG  2016      1  2016-01-01     1  16.15
# 2            HB_BUSAVG  2016      1  2016-01-01     2  15.61
# 3            HB_BUSAVG  2016      1  2016-01-01     3  15.62
# 4            HB_BUSAVG  2016      1  2016-01-01     4  15.94
# ...                ...   ...    ...         ...   ...    ...
# 497315         LZ_WEST  2019     12  2019-12-31    19  33.45
# 497316         LZ_WEST  2019     12  2019-12-31    20  31.49
# 497317         LZ_WEST  2019     12  2019-12-31    21  24.47
# 497318         LZ_WEST  2019     12  2019-12-31    22  19.17
# 497319         LZ_WEST  2019     12  2019-12-31    23  16.78
#
# [497320 rows x 6 columns]

# %%
t3=pd.DataFrame(t3.groupby([t3.SettlementPoint,t3.year,t3.month,t3.date]).apply(lambda x:np.log(x.Price).diff().std()))
# Out:
# /Users/Dorene/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/Dorene/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/Dorene/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py:1926: RuntimeWarning: invalid value encountered in subtract
#   out_arr[res_indexer] = arr[res_indexer] - arr[lag_indexer]

# %%
t3=t3.reset_index()
t3
# Out:
#       SettlementPoint  year  month        date         0
# 0           HB_BUSAVG  2016      1  2016-01-01  0.073215
# 1           HB_BUSAVG  2016      1  2016-01-02  0.073592
# 2           HB_BUSAVG  2016      1  2016-01-03  0.064709
# 3           HB_BUSAVG  2016      1  2016-01-04  0.245759
# 4           HB_BUSAVG  2016      1  2016-01-05  0.225209
# ...               ...   ...    ...         ...       ...
# 20719         LZ_WEST  2019     12  2019-12-27  0.230953
# 20720         LZ_WEST  2019     12  2019-12-28  0.206968
# 20721         LZ_WEST  2019     12  2019-12-29  0.279357
# 20722         LZ_WEST  2019     12  2019-12-30  0.352715
# 20723         LZ_WEST  2019     12  2019-12-31  0.270370
#
# [20724 rows x 5 columns]

# %%
import numpy as np
t3=t3.groupby([t3.SettlementPoint,t3.year,t3.month]).mean()
# t3=t3.reset_index()
# t3=pd.DataFrame(t3)

# %% [markdown]
# # task4

# %%
temp=pd.merge(t2_mean,t2_max,right_index=True,left_index=True)
temp=pd.merge(temp,t2_min,right_index=True,left_index=True)
temp=pd.merge(temp,t2_std,right_index=True,left_index=True)
temp=pd.merge(temp,t3,right_index=True,left_index=True)

# %%
temp.columns=["Year", "Month", "Mean", "Min", "Max", "SD", "Volatility"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-d40c8461b817> in <module>
# ----> 1 temp.columns=["Year", "Month", "Mean", "Min", "Max", "SD", "Volatility"]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ...

# %%
t4=temp
t4
# Out:
#                                Price_x              Date_x  Price_y  \
# SettlementPoint year month
# HB_BUSAVG       2016 1       19.209301 2016-01-31 23:00:00    54.69
#                      2       15.288247 2016-02-29 23:00:00    50.98
#                      3       16.755626 2016-03-31 23:00:00    64.31
#                      4       18.289347 2016-04-30 23:00:00    93.09
#                      5       18.159583 2016-05-31 23:00:00    73.61
# ...                                ...                 ...      ...
# LZ_WEST         2019 8      128.876465 2019-08-31 23:00:00  3505.60
#                      9       83.471139 2019-09-30 23:00:00  5015.25
#                      10      49.383360 2019-10-31 23:00:00   873.07
#                      11      49.340847 2019-11-30 23:00:00   286.91
#                      12      39.502594 2019-12-31 23:00:00   195.71
#
#                                Date_y  Price_x     Price_y  year  month  \
# SettlementPoint year month
# ...

# %%
t4.to_csv("MonthlyPowerPriceStatistics.csv")

# %% [markdown]
# # task5

# %%
cont
# Out:
#   ContractName         DealType   StartDate     EndDate  Volume Granularity  \
# 0           S1             Swap  2017-01-01  2017-03-31   20000       Daily
# 1           S2             Swap  2017-01-01  2018-12-31    1000      Hourly
# 2           O1  European option  2017-06-01  2017-07-15   10000       Daily
# 3           O2  European option  2018-10-01  2019-09-30    1000      Hourly
#
#    StrikePrice  Premium   PriceName
# 0          3.0      NaN   Henry Hub
# 1         21.0      NaN    HB_NORTH
# 2          2.9      0.1  GDA_TETSTX
# 3         31.5      3.0  HB_HOUSTON

# %%
cont.StartDate=cont.StartDate.apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d'))
cont.EndDate=cont.EndDate.apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d'))
cont
# Out:
#   ContractName         DealType  StartDate    EndDate  Volume Granularity  \
# 0           S1             Swap 2017-01-01 2017-03-31   20000       Daily
# 1           S2             Swap 2017-01-01 2018-12-31    1000      Hourly
# 2           O1  European option 2017-06-01 2017-07-15   10000       Daily
# 3           O2  European option 2018-10-01 2019-09-30    1000      Hourly
#
#    StrikePrice  Premium   PriceName
# 0          3.0      NaN   Henry Hub
# 1         21.0      NaN    HB_NORTH
# 2          2.9      0.1  GDA_TETSTX
# 3         31.5      3.0  HB_HOUSTON

# %%
cont.StartDate[0]
cont.loc[0,:]
# Out:
# ContractName                     S1
# DealType                       Swap
# StartDate       2017-01-01 00:00:00
# EndDate         2017-03-31 00:00:00
# Volume                        20000
# Granularity                   Daily
# StrikePrice                       3
# Premium                         NaN
# PriceName                 Henry Hub
# Name: 0, dtype: object

# %%
time_range = pd.date_range(cont.StartDate[0], cont.EndDate[0], freq='D')
s1=pd.DataFrame(index=time_range,columns=cont.columns)
s1
# Out:
#            ContractName DealType StartDate EndDate Volume Granularity  \
# 2017-01-01          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-01-02          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-01-03          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-01-04          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-01-05          NaN      NaN       NaN     NaN    NaN         NaN
# ...                 ...      ...       ...     ...    ...         ...
# 2017-03-27          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-03-28          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-03-29          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-03-30          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-03-31          NaN      NaN       NaN     NaN    NaN         NaN
#
#            StrikePrice Premium PriceName
# 2017-01-01         NaN     NaN       NaN
# 2017-01-02         NaN     NaN       NaN
# ...

# %%
time_range = pd.date_range(cont.StartDate[1], cont.EndDate[1], freq='H')
s2=pd.DataFrame(index=time_range,columns=cont.columns)
s2
# Out:
#                     ContractName DealType StartDate EndDate Volume  \
# 2017-01-01 00:00:00          NaN      NaN       NaN     NaN    NaN
# 2017-01-01 01:00:00          NaN      NaN       NaN     NaN    NaN
# 2017-01-01 02:00:00          NaN      NaN       NaN     NaN    NaN
# 2017-01-01 03:00:00          NaN      NaN       NaN     NaN    NaN
# 2017-01-01 04:00:00          NaN      NaN       NaN     NaN    NaN
# ...                          ...      ...       ...     ...    ...
# 2018-12-30 20:00:00          NaN      NaN       NaN     NaN    NaN
# 2018-12-30 21:00:00          NaN      NaN       NaN     NaN    NaN
# 2018-12-30 22:00:00          NaN      NaN       NaN     NaN    NaN
# 2018-12-30 23:00:00          NaN      NaN       NaN     NaN    NaN
# 2018-12-31 00:00:00          NaN      NaN       NaN     NaN    NaN
#
#                     Granularity StrikePrice Premium PriceName
# 2017-01-01 00:00:00         NaN         NaN     NaN       NaN
# ...

# %%
time_range = pd.date_range(cont.StartDate[2], cont.EndDate[2], freq='D')
o1=pd.DataFrame(index=time_range,columns=cont.columns)
o1
# Out:
#            ContractName DealType StartDate EndDate Volume Granularity  \
# 2017-06-01          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-02          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-03          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-04          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-05          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-06          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-07          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-08          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-09          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-10          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-11          NaN      NaN       NaN     NaN    NaN         NaN
# 2017-06-12          NaN      NaN       NaN     NaN    NaN         NaN
# ...

# %%
time_range = pd.date_range(cont.StartDate[3], cont.EndDate[3], freq='H')
o2=pd.DataFrame(index=time_range,columns=cont.columns)
o2
# Out:
#                     ContractName DealType StartDate EndDate Volume  \
# 2018-10-01 00:00:00          NaN      NaN       NaN     NaN    NaN
# 2018-10-01 01:00:00          NaN      NaN       NaN     NaN    NaN
# 2018-10-01 02:00:00          NaN      NaN       NaN     NaN    NaN
# 2018-10-01 03:00:00          NaN      NaN       NaN     NaN    NaN
# 2018-10-01 04:00:00          NaN      NaN       NaN     NaN    NaN
# ...                          ...      ...       ...     ...    ...
# 2019-09-29 20:00:00          NaN      NaN       NaN     NaN    NaN
# 2019-09-29 21:00:00          NaN      NaN       NaN     NaN    NaN
# 2019-09-29 22:00:00          NaN      NaN       NaN     NaN    NaN
# 2019-09-29 23:00:00          NaN      NaN       NaN     NaN    NaN
# 2019-09-30 00:00:00          NaN      NaN       NaN     NaN    NaN
#
#                     Granularity StrikePrice Premium PriceName
# 2018-10-01 00:00:00         NaN         NaN     NaN       NaN
# ...

# %%
t=[s1,s2,o1,o2]
for i in range(len(t)):
    s=t[i]
    s.ContractName=cont.loc[i,:].ContractName
    s.DealType=cont.loc[i,:].DealType
    s.StartDate=cont.loc[i,:].StartDate
    s.EndDate=cont.loc[i,:].EndDate
    s.Volume=cont.loc[i,:].Volume
    s.Granularity=cont.loc[i,:].Granularity
    s.StrikePrice=cont.loc[i,:].StrikePrice
    s.Premium=cont.loc[i,:].Premium
    s.PriceName=cont.loc[i,:].PriceName

# %%
s1
# Out:
#            ContractName DealType  StartDate    EndDate  Volume Granularity  \
# 2017-01-01           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-02           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-03           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-04           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-05           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# ...                 ...      ...        ...        ...     ...         ...
# 2017-03-27           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-28           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-29           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-30           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-31           S1     Swap 2017-01-01 2017-03-31   20000       Daily
#
#             StrikePrice  Premium  PriceName
# ...

# %% [markdown]
# # task6

# %%
henry=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/fuelPrices/Henry Hub.csv")
henry=henry.set_index("Date")
t6_s1=pd.merge(s1,henry,left_index=True,right_index=True).drop(columns=["Variable"])
t6_s1
# Out:
#            ContractName DealType  StartDate    EndDate  Volume Granularity  \
# 2017-01-01           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-02           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-03           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-04           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-05           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# ...                 ...      ...        ...        ...     ...         ...
# 2017-03-27           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-28           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-29           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-30           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-31           S1     Swap 2017-01-01 2017-03-31   20000       Daily
#
#             StrikePrice  Premium  PriceName  Price
# ...

# %%
gda=pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/fuelPrices/GDA_TETSTX.csv")
gda=gda.set_index("Date")
t6_o1=pd.merge(o1,gda,left_index=True,right_index=True).drop(columns=["Variable"])
t6_o1
# Out:
#            ContractName         DealType  StartDate    EndDate  Volume  \
# 2017-06-01           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-02           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-03           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-04           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-05           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-06           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-07           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-08           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-09           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-10           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-11           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-12           O1  European option 2017-06-01 2017-07-15   10000
# ...

# %%
cont
# Out:
#   ContractName         DealType  StartDate    EndDate  Volume Granularity  \
# 0           S1             Swap 2017-01-01 2017-03-31   20000       Daily
# 1           S2             Swap 2017-01-01 2018-12-31    1000      Hourly
# 2           O1  European option 2017-06-01 2017-07-15   10000       Daily
# 3           O2  European option 2018-10-01 2019-09-30    1000      Hourly
#
#    StrikePrice  Premium   PriceName
# 0          3.0      NaN   Henry Hub
# 1         21.0      NaN    HB_NORTH
# 2          2.9      0.1  GDA_TETSTX
# 3         31.5      3.0  HB_HOUSTON

# %%
hb=t2.loc[t2.SettlementPoint=="HB_NORTH",:].reset_index(drop=True).set_index("Date")
t6_s2=pd.merge(s2,hb,left_index=True,right_index=True)
t6_s2
# Out:
#                     ContractName DealType  StartDate    EndDate  Volume  \
# 2017-01-01 00:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2017-01-01 01:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2017-01-01 02:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2017-01-01 03:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2017-01-01 04:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# ...                          ...      ...        ...        ...     ...
# 2018-12-30 20:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2018-12-30 21:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2018-12-30 22:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2018-12-30 23:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2018-12-31 00:00:00           S2     Swap 2017-01-01 2018-12-31    1000
#
#                     Granularity  StrikePrice  Premium PriceName  \
# ...

# %%
hu=t2.loc[t2.SettlementPoint=="HB_HOUSTON",:].reset_index(drop=True).set_index("Date")
t6_o2=pd.merge(o2,hu,left_index=True,right_index=True)
t6_o2
# Out:
#                     ContractName         DealType  StartDate    EndDate  \
# 2018-10-01 00:00:00           O2  European option 2018-10-01 2019-09-30
# 2018-10-01 01:00:00           O2  European option 2018-10-01 2019-09-30
# 2018-10-01 02:00:00           O2  European option 2018-10-01 2019-09-30
# 2018-10-01 03:00:00           O2  European option 2018-10-01 2019-09-30
# 2018-10-01 04:00:00           O2  European option 2018-10-01 2019-09-30
# ...                          ...              ...        ...        ...
# 2019-09-29 20:00:00           O2  European option 2018-10-01 2019-09-30
# 2019-09-29 21:00:00           O2  European option 2018-10-01 2019-09-30
# 2019-09-29 22:00:00           O2  European option 2018-10-01 2019-09-30
# 2019-09-29 23:00:00           O2  European option 2018-10-01 2019-09-30
# 2019-09-30 00:00:00           O2  European option 2018-10-01 2019-09-30
#
#                      Volume Granularity  StrikePrice  Premium   PriceName  \
# ...

# %% [markdown]
# # task7

# %%
t6_s1.loc[:,"payoffs"]=(t6_s1.loc[:,"Price"]-t6_s1.loc[:,"StrikePrice"])*t6_s1.loc[:,"Volume"]
t6_s1
# Out:
#            ContractName DealType  StartDate    EndDate  Volume Granularity  \
# 2017-01-01           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-02           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-03           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-04           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-01-05           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# ...                 ...      ...        ...        ...     ...         ...
# 2017-03-27           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-28           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-29           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-30           S1     Swap 2017-01-01 2017-03-31   20000       Daily
# 2017-03-31           S1     Swap 2017-01-01 2017-03-31   20000       Daily
#
#             StrikePrice  Premium  PriceName  Price  payoffs
# ...

# %%
t6_s2.loc[:,"payoffs"]=(t6_s2.loc[:,"Price"]-t6_s2.loc[:,"StrikePrice"])*t6_s2.loc[:,"Volume"]
t6_s2
# Out:
#                     ContractName DealType  StartDate    EndDate  Volume  \
# 2017-01-01 00:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2017-01-01 01:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2017-01-01 02:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2017-01-01 03:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2017-01-01 04:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# ...                          ...      ...        ...        ...     ...
# 2018-12-30 20:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2018-12-30 21:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2018-12-30 22:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2018-12-30 23:00:00           S2     Swap 2017-01-01 2018-12-31    1000
# 2018-12-31 00:00:00           S2     Swap 2017-01-01 2018-12-31    1000
#
#                     Granularity  StrikePrice  Premium PriceName  \
# ...

# %%
t6_o1
# Out:
#            ContractName         DealType  StartDate    EndDate  Volume  \
# 2017-06-01           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-02           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-03           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-04           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-05           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-06           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-07           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-08           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-09           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-10           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-11           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-12           O1  European option 2017-06-01 2017-07-15   10000
# ...

# %%
t6_o1.loc[:,"payoffs"]=(t6_o1.loc[:,"Price"]-t6_o1.loc[:,"StrikePrice"]).clip(0, None)*t6_o1.loc[:,"Volume"]
t6_o1
# Out:
#            ContractName         DealType  StartDate    EndDate  Volume  \
# 2017-06-01           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-02           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-03           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-04           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-05           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-06           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-07           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-08           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-09           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-10           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-11           O1  European option 2017-06-01 2017-07-15   10000
# 2017-06-12           O1  European option 2017-06-01 2017-07-15   10000
# ...

# %%
t6_o2.loc[:,"payoffs"]=(t6_o2.loc[:,"Price"]-t6_o2.loc[:,"StrikePrice"]).clip(0, None)*t6_o2.loc[:,"Volume"]
t6_o2
# Out:
#                     ContractName         DealType  StartDate    EndDate  \
# 2018-10-01 00:00:00           O2  European option 2018-10-01 2019-09-30
# 2018-10-01 01:00:00           O2  European option 2018-10-01 2019-09-30
# 2018-10-01 02:00:00           O2  European option 2018-10-01 2019-09-30
# 2018-10-01 03:00:00           O2  European option 2018-10-01 2019-09-30
# 2018-10-01 04:00:00           O2  European option 2018-10-01 2019-09-30
# ...                          ...              ...        ...        ...
# 2019-09-29 20:00:00           O2  European option 2018-10-01 2019-09-30
# 2019-09-29 21:00:00           O2  European option 2018-10-01 2019-09-30
# 2019-09-29 22:00:00           O2  European option 2018-10-01 2019-09-30
# 2019-09-29 23:00:00           O2  European option 2018-10-01 2019-09-30
# 2019-09-30 00:00:00           O2  European option 2018-10-01 2019-09-30
#
#                      Volume Granularity  StrikePrice  Premium   PriceName  \
# ...

# %% [markdown]
# # task8

# %%
t8_s1=t6_s1.groupby([t6_s1.index.year,t6_s1.index.month])["payoffs"].sum().reset_index().rename(columns={"level_0":"Year","level_1":"Month"})
t8_s1.loc[:,"ContractName"]="S1"
t8_s1
# Out:
#    Year  Month   payoffs ContractName
# 0  2017      1  198300.0           S1
# 1  2017      2  -97700.0           S1
# 2  2017      3  -97700.0           S1

# %%
t8_s2=t6_s2.groupby([t6_s2.index.year,t6_s2.index.month])["payoffs"].sum().reset_index().rename(columns={"level_0":"Year","level_1":"Month"})
t8_s2.loc[:,"ContractName"]="S2"

# %%
t8_o1=t6_o1.groupby([t6_o1.index.year,t6_o1.index.month])["payoffs"].sum().reset_index().rename(columns={"level_0":"Year","level_1":"Month"})
t8_o1.loc[:,"ContractName"]="O1"

# %%
t8_o2=t6_o2.groupby([t6_o2.index.year,t6_o2.index.month])["payoffs"].sum().reset_index().rename(columns={"level_0":"Year","level_1":"Month"})
t8_o2.loc[:,"ContractName"]="O2"

# %%
t8=pd.concat([t8_s1,t8_s2,t8_o1,t8_o2],ignore_index=True)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # task9

# %%
t8.to_csv("MonthlyContractPayoffs.csv")

# %%
t8
# Out:
#     Year  Month     payoffs ContractName
# 0   2017      1    198300.0           S1
# 1   2017      2    -97700.0           S1
# 2   2017      3    -97700.0           S1
# 3   2017      1   1481940.0           S2
# 4   2017      2  -1042810.0           S2
# 5   2017      3    169240.0           S2
# 6   2017      4    295600.0           S2
# 7   2017      5   1800420.0           S2
# 8   2017      6   3521210.0           S2
# 9   2017      7   7182810.0           S2
# 10  2017      8   4339550.0           S2
# 11  2017      9   1689200.0           S2
# 12  2017     10    301990.0           S2
# 13  2017     11    429270.0           S2
# 14  2017     12    -34970.0           S2
# 15  2018      1  12339910.0           S2
# 16  2018      2    515440.0           S2
# 17  2018      3   1194750.0           S2
# 18  2018      4   1816500.0           S2
# 19  2018      5  10643770.0           S2
# 20  2018      6   6632560.0           S2
# 21  2018      7  43128530.0           S2
# ...

# %% [markdown]
# # task 10

# %%
data = pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/plantParameters/Plant_Parameters.csv")
Henry_Hub = pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/fuelPrices/Henry Hub.csv")
GDA_TETSTX = pd.read_csv("/Users/Dorene/Desktop/model-dev-coding-exercise-public-master 2/fuelPrices/GDA_TETSTX.csv")

Henry_Hub['Date'] = pd.to_datetime(Henry_Hub['Date'])
GDA_TETSTX['Date'] = pd.to_datetime(GDA_TETSTX['Date'])

Henry_Hub1718 = Henry_Hub[pd.DatetimeIndex(Henry_Hub['Date']).year.isin([2017,2018])]
GDA_TETSTX1718 = GDA_TETSTX[pd.DatetimeIndex(GDA_TETSTX['Date']).year.isin([2017,2018])]

Henry_Hub1718['year'] = pd.DatetimeIndex(Henry_Hub1718['Date']).year
Henry_Hub1718['month'] = pd.DatetimeIndex(Henry_Hub1718['Date']).month
GDA_TETSTX1718['year'] = pd.DatetimeIndex(GDA_TETSTX1718['Date']).year
GDA_TETSTX1718['month'] = pd.DatetimeIndex(GDA_TETSTX1718['Date']).month

Henry_Hub1718J = Henry_Hub1718.merge(data, how='left', left_on=['Variable', 'year','month'], right_on=['FuelPriceName', 'Year','Month'])
GDA_TETSTX1718J = GDA_TETSTX1718.merge(data, how='inner', left_on=['Variable', 'year','month'], right_on=['FuelPriceName', 'Year','Month'])


Joined = pd.concat([Henry_Hub1718J,GDA_TETSTX1718J], axis = 0)

Joined['RunningCost'] = (Joined['Price'] + Joined['FuelTransportationCost'])*Joined['HeatRate'] + Joined['VOM']

Joined['RunningCost']
# Out:
# <ipython-input-53-4ee1b9d13713>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Henry_Hub1718['year'] = pd.DatetimeIndex(Henry_Hub1718['Date']).year
# <ipython-input-53-4ee1b9d13713>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Henry_Hub1718['month'] = pd.DatetimeIndex(Henry_Hub1718['Date']).month
# <ipython-input-53-4ee1b9d13713>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# # task 11
